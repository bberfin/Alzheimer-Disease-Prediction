# %%
#IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
#IMPORT / VIEWING / PREPROCESSING DATASET

# %%
#DATA AUGMENTATION

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/train',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 256)
# Out:
# Found 4098 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/train',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 256)
# Out:
# Found 1023 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Dementia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [10:59<00:00, 131.82s/it]

# %%
#MODEL BUILDING

# %%
base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 3s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 7, 7, 1664)        12642880
#
#  dropout (Dropout)           (None, 7, 7, 1664)        0
#
#  flatten (Flatten)           (None, 81536)             0
#
#  batch_normalization (BatchN  (None, 81536)            326144
#  ormalization)
#
#  dense (Dense)               (None, 2048)              166987776
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  activation (Activation)     (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 182,071,364
# Trainable params: 169,259,268
# Non-trainable params: 12,812,096
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Defining Callbacks

filepath = '/content/drive/MyDrive/Colab Notebooks/best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 100,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# 17/17 [==============================] - ETA: 0s - loss: 1.3679 - auc: 0.7773
# Epoch 1: val_auc improved from -inf to 0.69408, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 2417s 140s/step - loss: 1.3679 - auc: 0.7773 - val_loss: 7.2814 - val_auc: 0.6941
# Epoch 2/100
# 17/17 [==============================] - ETA: 0s - loss: 1.0932 - auc: 0.8327
# Epoch 2: val_auc did not improve from 0.69408
# 17/17 [==============================] - 61s 4s/step - loss: 1.0932 - auc: 0.8327 - val_loss: 7.0531 - val_auc: 0.6738
# Epoch 3/100
# 17/17 [==============================] - ETA: 0s - loss: 1.0212 - auc: 0.8467
# Epoch 3: val_auc improved from 0.69408 to 0.72787, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 72s 4s/step - loss: 1.0212 - auc: 0.8467 - val_loss: 2.8726 - val_auc: 0.7279
# Epoch 4/100
# 17/17 [==============================] - ETA: 0s - loss: 0.9622 - auc: 0.8587
# Epoch 4: val_auc did not improve from 0.72787
# 17/17 [==============================] - 61s 4s/step - loss: 0.9622 - auc: 0.8587 - val_loss: 2.6478 - val_auc: 0.7178
# Epoch 5/100
# 17/17 [==============================] - ETA: 0s - loss: 0.9227 - auc: 0.8650
# Epoch 5: val_auc did not improve from 0.72787
# 17/17 [==============================] - 56s 3s/step - loss: 0.9227 - auc: 0.8650 - val_loss: 2.5396 - val_auc: 0.7058
# Epoch 6/100
# 17/17 [==============================] - ETA: 0s - loss: 0.8942 - auc: 0.8746
# Epoch 6: val_auc did not improve from 0.72787
# 17/17 [==============================] - 56s 3s/step - loss: 0.8942 - auc: 0.8746 - val_loss: 2.6063 - val_auc: 0.7248
# Epoch 7/100
# 17/17 [==============================] - ETA: 0s - loss: 0.8539 - auc: 0.8819
# Epoch 7: val_auc improved from 0.72787 to 0.76172, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 73s 4s/step - loss: 0.8539 - auc: 0.8819 - val_loss: 1.9522 - val_auc: 0.7617
# Epoch 8/100
# 17/17 [==============================] - ETA: 0s - loss: 0.8491 - auc: 0.8816
# Epoch 8: val_auc improved from 0.76172 to 0.76630, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 71s 4s/step - loss: 0.8491 - auc: 0.8816 - val_loss: 1.5796 - val_auc: 0.7663
# Epoch 9/100
# 17/17 [==============================] - ETA: 0s - loss: 0.7900 - auc: 0.8936
# Epoch 9: val_auc did not improve from 0.76630
# 17/17 [==============================] - 61s 4s/step - loss: 0.7900 - auc: 0.8936 - val_loss: 1.7888 - val_auc: 0.7601
# Epoch 10/100
# 17/17 [==============================] - ETA: 0s - loss: 0.8005 - auc: 0.8921
# Epoch 10: val_auc improved from 0.76630 to 0.77609, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 72s 5s/step - loss: 0.8005 - auc: 0.8921 - val_loss: 1.4032 - val_auc: 0.7761
# Epoch 11/100
# 17/17 [==============================] - ETA: 0s - loss: 0.7631 - auc: 0.8999
# Epoch 11: val_auc improved from 0.77609 to 0.78677, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 77s 5s/step - loss: 0.7631 - auc: 0.8999 - val_loss: 1.2628 - val_auc: 0.7868
# Epoch 12/100
# 17/17 [==============================] - ETA: 0s - loss: 0.7681 - auc: 0.8985
# Epoch 12: val_auc improved from 0.78677 to 0.79651, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 79s 5s/step - loss: 0.7681 - auc: 0.8985 - val_loss: 1.4596 - val_auc: 0.7965
# Epoch 13/100
# 17/17 [==============================] - ETA: 0s - loss: 0.7405 - auc: 0.9052
# Epoch 13: val_auc did not improve from 0.79651
# 17/17 [==============================] - 61s 4s/step - loss: 0.7405 - auc: 0.9052 - val_loss: 1.4534 - val_auc: 0.7865
# Epoch 14/100
# 17/17 [==============================] - ETA: 0s - loss: 0.7353 - auc: 0.9065
# Epoch 14: val_auc did not improve from 0.79651
# 17/17 [==============================] - 57s 3s/step - loss: 0.7353 - auc: 0.9065 - val_loss: 1.6105 - val_auc: 0.7883
# Epoch 15/100
# 17/17 [==============================] - ETA: 0s - loss: 0.7021 - auc: 0.9135
# Epoch 15: val_auc improved from 0.79651 to 0.82043, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 72s 4s/step - loss: 0.7021 - auc: 0.9135 - val_loss: 1.1862 - val_auc: 0.8204
# Epoch 16/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6929 - auc: 0.9155
# Epoch 16: val_auc did not improve from 0.82043
# 17/17 [==============================] - 59s 3s/step - loss: 0.6929 - auc: 0.9155 - val_loss: 1.2507 - val_auc: 0.8199
# Epoch 17/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6618 - auc: 0.9233
# Epoch 17: val_auc did not improve from 0.82043
# 17/17 [==============================] - 56s 3s/step - loss: 0.6618 - auc: 0.9233 - val_loss: 1.4126 - val_auc: 0.7909
# Epoch 18/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6786 - auc: 0.9192
# Epoch 18: val_auc did not improve from 0.82043
# 17/17 [==============================] - 55s 3s/step - loss: 0.6786 - auc: 0.9192 - val_loss: 1.3957 - val_auc: 0.7708
# Epoch 19/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6622 - auc: 0.9236
# Epoch 19: val_auc improved from 0.82043 to 0.82565, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 71s 4s/step - loss: 0.6622 - auc: 0.9236 - val_loss: 1.2187 - val_auc: 0.8256
# Epoch 20/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6741 - auc: 0.9206
# Epoch 20: val_auc did not improve from 0.82565
# 17/17 [==============================] - 60s 3s/step - loss: 0.6741 - auc: 0.9206 - val_loss: 1.2711 - val_auc: 0.8123
# Epoch 21/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6390 - auc: 0.9277
# Epoch 21: val_auc did not improve from 0.82565
# 17/17 [==============================] - 55s 3s/step - loss: 0.6390 - auc: 0.9277 - val_loss: 1.3845 - val_auc: 0.8022
# Epoch 22/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6266 - auc: 0.9299
# Epoch 22: val_auc did not improve from 0.82565
# 17/17 [==============================] - 55s 3s/step - loss: 0.6266 - auc: 0.9299 - val_loss: 1.2332 - val_auc: 0.8144
# Epoch 23/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6489 - auc: 0.9270
# Epoch 23: val_auc did not improve from 0.82565
# 17/17 [==============================] - 54s 3s/step - loss: 0.6489 - auc: 0.9270 - val_loss: 1.3456 - val_auc: 0.8120
# Epoch 24/100
# 17/17 [==============================] - ETA: 0s - loss: 0.6379 - auc: 0.9290
# Epoch 24: val_auc did not improve from 0.82565
# 17/17 [==============================] - 54s 3s/step - loss: 0.6379 - auc: 0.9290 - val_loss: 1.2702 - val_auc: 0.8182
# Epoch 25/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5905 - auc: 0.9373
# Epoch 25: val_auc did not improve from 0.82565
# 17/17 [==============================] - 56s 3s/step - loss: 0.5905 - auc: 0.9373 - val_loss: 1.3159 - val_auc: 0.8036
# Epoch 26/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5826 - auc: 0.9384
# Epoch 26: val_auc did not improve from 0.82565
# 17/17 [==============================] - 55s 3s/step - loss: 0.5826 - auc: 0.9384 - val_loss: 1.2676 - val_auc: 0.8141
# Epoch 27/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5768 - auc: 0.9400
# Epoch 27: val_auc improved from 0.82565 to 0.82641, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 71s 4s/step - loss: 0.5768 - auc: 0.9400 - val_loss: 1.2222 - val_auc: 0.8264
# Epoch 28/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5793 - auc: 0.9399
# Epoch 28: val_auc did not improve from 0.82641
# 17/17 [==============================] - 59s 3s/step - loss: 0.5793 - auc: 0.9399 - val_loss: 1.2274 - val_auc: 0.8230
# Epoch 29/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5683 - auc: 0.9413
# Epoch 29: val_auc improved from 0.82641 to 0.82814, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 71s 4s/step - loss: 0.5683 - auc: 0.9413 - val_loss: 1.2082 - val_auc: 0.8281
# Epoch 30/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5598 - auc: 0.9437
# Epoch 30: val_auc improved from 0.82814 to 0.83015, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 77s 5s/step - loss: 0.5598 - auc: 0.9437 - val_loss: 1.3005 - val_auc: 0.8301
# Epoch 31/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5592 - auc: 0.9432
# Epoch 31: val_auc did not improve from 0.83015
# 17/17 [==============================] - 60s 4s/step - loss: 0.5592 - auc: 0.9432 - val_loss: 1.3721 - val_auc: 0.8276
# Epoch 32/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5840 - auc: 0.9398
# Epoch 32: val_auc improved from 0.83015 to 0.84678, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 72s 4s/step - loss: 0.5840 - auc: 0.9398 - val_loss: 1.2115 - val_auc: 0.8468
# Epoch 33/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5323 - auc: 0.9488
# Epoch 33: val_auc did not improve from 0.84678
# 17/17 [==============================] - 59s 3s/step - loss: 0.5323 - auc: 0.9488 - val_loss: 1.2872 - val_auc: 0.8327
# Epoch 34/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5340 - auc: 0.9487
# Epoch 34: val_auc did not improve from 0.84678
# 17/17 [==============================] - 55s 3s/step - loss: 0.5340 - auc: 0.9487 - val_loss: 1.2258 - val_auc: 0.8423
# Epoch 35/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5561 - auc: 0.9452
# Epoch 35: val_auc did not improve from 0.84678
# 17/17 [==============================] - 55s 3s/step - loss: 0.5561 - auc: 0.9452 - val_loss: 1.1889 - val_auc: 0.8373
# Epoch 36/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5557 - auc: 0.9448
# Epoch 36: val_auc did not improve from 0.84678
# 17/17 [==============================] - 54s 3s/step - loss: 0.5557 - auc: 0.9448 - val_loss: 1.3557 - val_auc: 0.8319
# Epoch 37/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5246 - auc: 0.9497
# Epoch 37: val_auc did not improve from 0.84678
# 17/17 [==============================] - 55s 3s/step - loss: 0.5246 - auc: 0.9497 - val_loss: 1.2040 - val_auc: 0.8380
# Epoch 38/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5511 - auc: 0.9453
# Epoch 38: val_auc did not improve from 0.84678
# 17/17 [==============================] - 54s 3s/step - loss: 0.5511 - auc: 0.9453 - val_loss: 1.2980 - val_auc: 0.8332
# Epoch 39/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5550 - auc: 0.9454
# Epoch 39: val_auc did not improve from 0.84678
# 17/17 [==============================] - 55s 3s/step - loss: 0.5550 - auc: 0.9454 - val_loss: 1.6471 - val_auc: 0.8101
# Epoch 40/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5049 - auc: 0.9537
# Epoch 40: val_auc did not improve from 0.84678
# 17/17 [==============================] - 55s 3s/step - loss: 0.5049 - auc: 0.9537 - val_loss: 1.3202 - val_auc: 0.8310
# Epoch 41/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5053 - auc: 0.9534
# Epoch 41: val_auc improved from 0.84678 to 0.87052, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 70s 4s/step - loss: 0.5053 - auc: 0.9534 - val_loss: 1.0205 - val_auc: 0.8705
# Epoch 42/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5319 - auc: 0.9487
# Epoch 42: val_auc did not improve from 0.87052
# 17/17 [==============================] - 59s 3s/step - loss: 0.5319 - auc: 0.9487 - val_loss: 1.4629 - val_auc: 0.8355
# Epoch 43/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5391 - auc: 0.9483
# Epoch 43: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.5391 - auc: 0.9483 - val_loss: 1.2769 - val_auc: 0.8358
# Epoch 44/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5264 - auc: 0.9499
# Epoch 44: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.5264 - auc: 0.9499 - val_loss: 1.3469 - val_auc: 0.8295
# Epoch 45/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5192 - auc: 0.9514
# Epoch 45: val_auc did not improve from 0.87052
# 17/17 [==============================] - 54s 3s/step - loss: 0.5192 - auc: 0.9514 - val_loss: 1.1416 - val_auc: 0.8523
# Epoch 46/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5300 - auc: 0.9490
# Epoch 46: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.5300 - auc: 0.9490 - val_loss: 1.2262 - val_auc: 0.8392
# Epoch 47/100
# 17/17 [==============================] - ETA: 0s - loss: 0.5020 - auc: 0.9537
# Epoch 47: val_auc did not improve from 0.87052
# 17/17 [==============================] - 54s 3s/step - loss: 0.5020 - auc: 0.9537 - val_loss: 1.1258 - val_auc: 0.8541
# Epoch 48/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4708 - auc: 0.9596
# Epoch 48: val_auc did not improve from 0.87052
# 17/17 [==============================] - 54s 3s/step - loss: 0.4708 - auc: 0.9596 - val_loss: 1.1400 - val_auc: 0.8662
# Epoch 49/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4735 - auc: 0.9590
# Epoch 49: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.4735 - auc: 0.9590 - val_loss: 1.1662 - val_auc: 0.8600
# Epoch 50/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4781 - auc: 0.9582
# Epoch 50: val_auc did not improve from 0.87052
# 17/17 [==============================] - 54s 3s/step - loss: 0.4781 - auc: 0.9582 - val_loss: 1.2587 - val_auc: 0.8543
# Epoch 51/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4561 - auc: 0.9618
# Epoch 51: val_auc did not improve from 0.87052
# 17/17 [==============================] - 54s 3s/step - loss: 0.4561 - auc: 0.9618 - val_loss: 1.3280 - val_auc: 0.8470
# Epoch 52/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4823 - auc: 0.9580
# Epoch 52: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.4823 - auc: 0.9580 - val_loss: 1.1373 - val_auc: 0.8570
# Epoch 53/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4760 - auc: 0.9586
# Epoch 53: val_auc did not improve from 0.87052
# 17/17 [==============================] - 54s 3s/step - loss: 0.4760 - auc: 0.9586 - val_loss: 1.2027 - val_auc: 0.8589
# Epoch 54/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4558 - auc: 0.9623
# Epoch 54: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.4558 - auc: 0.9623 - val_loss: 1.1428 - val_auc: 0.8625
# Epoch 55/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4583 - auc: 0.9614
# Epoch 55: val_auc did not improve from 0.87052
# 17/17 [==============================] - 55s 3s/step - loss: 0.4583 - auc: 0.9614 - val_loss: 1.1627 - val_auc: 0.8619
# Epoch 56/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4323 - auc: 0.9658
# Epoch 56: val_auc improved from 0.87052 to 0.87124, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 70s 4s/step - loss: 0.4323 - auc: 0.9658 - val_loss: 1.1050 - val_auc: 0.8712
# Epoch 57/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4558 - auc: 0.9619
# Epoch 57: val_auc did not improve from 0.87124
# 17/17 [==============================] - 59s 3s/step - loss: 0.4558 - auc: 0.9619 - val_loss: 1.0730 - val_auc: 0.8647
# Epoch 58/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4686 - auc: 0.9599
# Epoch 58: val_auc did not improve from 0.87124
# 17/17 [==============================] - 55s 3s/step - loss: 0.4686 - auc: 0.9599 - val_loss: 1.1209 - val_auc: 0.8642
# Epoch 59/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4655 - auc: 0.9603
# Epoch 59: val_auc did not improve from 0.87124
# 17/17 [==============================] - 55s 3s/step - loss: 0.4655 - auc: 0.9603 - val_loss: 1.1847 - val_auc: 0.8533
# Epoch 60/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4298 - auc: 0.9663
# Epoch 60: val_auc improved from 0.87124 to 0.87181, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 72s 4s/step - loss: 0.4298 - auc: 0.9663 - val_loss: 1.0382 - val_auc: 0.8718
# Epoch 61/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4361 - auc: 0.9651
# Epoch 61: val_auc did not improve from 0.87181
# 17/17 [==============================] - 60s 3s/step - loss: 0.4361 - auc: 0.9651 - val_loss: 1.1130 - val_auc: 0.8624
# Epoch 62/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4582 - auc: 0.9620
# Epoch 62: val_auc did not improve from 0.87181
# 17/17 [==============================] - 56s 3s/step - loss: 0.4582 - auc: 0.9620 - val_loss: 1.2259 - val_auc: 0.8525
# Epoch 63/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4333 - auc: 0.9654
# Epoch 63: val_auc improved from 0.87181 to 0.87792, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 74s 4s/step - loss: 0.4333 - auc: 0.9654 - val_loss: 1.0175 - val_auc: 0.8779
# Epoch 64/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4473 - auc: 0.9632
# Epoch 64: val_auc did not improve from 0.87792
# 17/17 [==============================] - 61s 4s/step - loss: 0.4473 - auc: 0.9632 - val_loss: 1.1614 - val_auc: 0.8650
# Epoch 65/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4318 - auc: 0.9655
# Epoch 65: val_auc did not improve from 0.87792
# 17/17 [==============================] - 55s 3s/step - loss: 0.4318 - auc: 0.9655 - val_loss: 1.1260 - val_auc: 0.8656
# Epoch 66/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4382 - auc: 0.9646
# Epoch 66: val_auc improved from 0.87792 to 0.87956, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 17/17 [==============================] - 72s 4s/step - loss: 0.4382 - auc: 0.9646 - val_loss: 1.0041 - val_auc: 0.8796
# Epoch 67/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4174 - auc: 0.9677
# Epoch 67: val_auc did not improve from 0.87956
# 17/17 [==============================] - 62s 4s/step - loss: 0.4174 - auc: 0.9677 - val_loss: 1.1358 - val_auc: 0.8620
# Epoch 68/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4144 - auc: 0.9682
# Epoch 68: val_auc did not improve from 0.87956
# 17/17 [==============================] - 56s 3s/step - loss: 0.4144 - auc: 0.9682 - val_loss: 1.4070 - val_auc: 0.8377
# Epoch 69/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4221 - auc: 0.9672
# Epoch 69: val_auc did not improve from 0.87956
# 17/17 [==============================] - 57s 3s/step - loss: 0.4221 - auc: 0.9672 - val_loss: 1.2370 - val_auc: 0.8490
# Epoch 70/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4870 - auc: 0.9574
# Epoch 70: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.4870 - auc: 0.9574 - val_loss: 1.1721 - val_auc: 0.8578
# Epoch 71/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4310 - auc: 0.9663
# Epoch 71: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.4310 - auc: 0.9663 - val_loss: 1.2560 - val_auc: 0.8507
# Epoch 72/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4476 - auc: 0.9635
# Epoch 72: val_auc did not improve from 0.87956
# 17/17 [==============================] - 56s 3s/step - loss: 0.4476 - auc: 0.9635 - val_loss: 1.4095 - val_auc: 0.8438
# Epoch 73/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4240 - auc: 0.9671
# Epoch 73: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.4240 - auc: 0.9671 - val_loss: 1.0845 - val_auc: 0.8759
# Epoch 74/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4162 - auc: 0.9681
# Epoch 74: val_auc did not improve from 0.87956
# 17/17 [==============================] - 56s 3s/step - loss: 0.4162 - auc: 0.9681 - val_loss: 1.3044 - val_auc: 0.8492
# Epoch 75/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4136 - auc: 0.9687
# Epoch 75: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.4136 - auc: 0.9687 - val_loss: 1.0972 - val_auc: 0.8759
# Epoch 76/100
# 17/17 [==============================] - ETA: 0s - loss: 0.3994 - auc: 0.9702
# Epoch 76: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.3994 - auc: 0.9702 - val_loss: 1.2564 - val_auc: 0.8642
# Epoch 77/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4059 - auc: 0.9696
# Epoch 77: val_auc did not improve from 0.87956
# 17/17 [==============================] - 56s 3s/step - loss: 0.4059 - auc: 0.9696 - val_loss: 1.1538 - val_auc: 0.8732
# Epoch 78/100
# 17/17 [==============================] - ETA: 0s - loss: 0.3635 - auc: 0.9754
# Epoch 78: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.3635 - auc: 0.9754 - val_loss: 1.0870 - val_auc: 0.8753
# Epoch 79/100
# 17/17 [==============================] - ETA: 0s - loss: 0.3859 - auc: 0.9725
# Epoch 79: val_auc did not improve from 0.87956
# 17/17 [==============================] - 56s 3s/step - loss: 0.3859 - auc: 0.9725 - val_loss: 1.1670 - val_auc: 0.8657
# Epoch 80/100
# 17/17 [==============================] - ETA: 0s - loss: 0.3927 - auc: 0.9712
# Epoch 80: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.3927 - auc: 0.9712 - val_loss: 1.0628 - val_auc: 0.8736
# Epoch 81/100
# 17/17 [==============================] - ETA: 0s - loss: 0.4411 - auc: 0.9639
# Epoch 81: val_auc did not improve from 0.87956
# 17/17 [==============================] - 55s 3s/step - loss: 0.4411 - auc: 0.9639 - val_loss: 1.0754 - val_auc: 0.8763
# Epoch 81: early stopping

# %%
#MODEL EVALUATION

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Test Data 

test_dataset  = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test',
                                                 target_size = (224,224),
                                                 class_mode = 'categorical',
                                                 batch_size = 128)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
# Evaluating Loss and AUC

model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 418s 46s/step - loss: 1.0184 - auc: 0.8926
# [1.0183966159820557, 0.8926005363464355]

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Non_Demented/26 (100).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 52ms/step
# 99.7 % chances are there that the image is Non_Demented

# %%
# Test Case 2: Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Mild_Demented/26 (19).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 97.09 % chances are there that the image is Mild_Demented

# %%
# Test Case 3: Moderate Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Moderate_Demented/27 (2).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 46ms/step
# 98.93 % chances are there that the image is Moderate_Demented

# %%
# Test Case 4: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Very_Mild_Demented/26 (55).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 49ms/step
# 65.03 % chances are there that the image is Very_Mild_Demented

# %%
# Test Case 5: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Very_Mild_Demented/26 (55).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 98ms/step
# 65.03 % chances are there that the image is Very_Mild_Demented

# %%
#Conclusion:

#So, we have finally built are deep learning model using DenseNet162 transfer learning algorithm and acheived and AUC-90%.
