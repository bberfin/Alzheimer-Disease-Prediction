# %%
#IMPORT LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import skimage.io
import os 
import tqdm
import glob
import tensorflow 

from tqdm import tqdm
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import grey2rgb

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, BatchNormalization, Dropout, Flatten, Dense, Activation, MaxPool2D, Conv2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.applications.densenet import DenseNet169
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# %%
#IMPORT / VIEWING / PREPROCESSING DATASET

# %%
#DATA AUGMENTATION

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   rotation_range=30,
                                   zoom_range=0.2,
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   validation_split = 0.2)

valid_datagen = ImageDataGenerator(rescale = 1./255,
                                   validation_split = 0.2)

test_datagen  = ImageDataGenerator(rescale = 1./255)

# %%
train_dataset  = train_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/Dataset',
                                                   target_size = (224,224),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   batch_size = 256)
# Out:
# Found 5121 images belonging to 4 classes.

# %%
valid_dataset = valid_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/Dataset',
                                                  target_size = (224,224),
                                                  class_mode = 'categorical',
                                                  subset = 'validation',
                                                  batch_size = 256)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 5, figsize=(20,20))

for i in tqdm(range(0,5)):
    rand1 = np.random.randint(len(train_dataset))
    rand2 = np.random.randint(100)
    ax[i].imshow(train_dataset[rand1][0][rand2])
    ax[i].axis('off')
    a = train_dataset[rand1][1][rand2]
    if a[0] == 1:
        ax[i].set_title('Mild Dementia')
    elif a[1] == 1:
        ax[i].set_title('Moderate Dementia')
    elif a[2] == 1:
        ax[i].set_title('Non Dementia')
    elif a[3] == 1:
        ax[i].set_title('Very Mild Dementia')
# Out:
# 100%|██████████| 5/5 [01:54<00:00, 22.83s/it]

# %%
#MODEL BUILDING

# %%
base_model = DenseNet169(input_shape=(224,224,3), 
                         include_top=False,
                         weights="imagenet")
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet169_weights_tf_dim_ordering_tf_kernels_notop.h5
# 51877672/51877672 [==============================] - 1s 0us/step

# %%
# Freezing Layers

for layer in base_model.layers:
    layer.trainable=False

# %%
# Building Model

model=Sequential()
model.add(base_model)
model.add(Dropout(0.5))
model.add(Flatten())
model.add(BatchNormalization())
model.add(Dense(2048,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1024,kernel_initializer='he_uniform'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4,activation='softmax'))

# %%
# Summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  densenet169 (Functional)    (None, 7, 7, 1664)        12642880
#
#  dropout (Dropout)           (None, 7, 7, 1664)        0
#
#  flatten (Flatten)           (None, 81536)             0
#
#  batch_normalization (BatchN  (None, 81536)            326144
#  ormalization)
#
#  dense (Dense)               (None, 2048)              166987776
#
#  batch_normalization_1 (Batc  (None, 2048)             8192
#  hNormalization)
#
#  activation (Activation)     (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense_1 (Dense)             (None, 1024)              2098176
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  activation_1 (Activation)   (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_2 (Dense)             (None, 4)                 4100
#
# =================================================================
# Total params: 182,071,364
# Trainable params: 169,259,268
# Non-trainable params: 12,812,096
# _________________________________________________________________

# %%
# Model Compile 

OPT    = tensorflow.keras.optimizers.Adam(lr=0.001)

model.compile(loss='categorical_crossentropy',
              metrics=[tensorflow.keras.metrics.AUC(name = 'auc')],
              optimizer=OPT)
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
# Defining Callbacks

filepath = '/content/drive/MyDrive/Colab Notebooks/best_weights.hdf5'

earlystopping = EarlyStopping(monitor = 'val_auc', 
                              mode = 'max' , 
                              patience = 15,
                              verbose = 1)

checkpoint    = ModelCheckpoint(filepath, 
                                monitor = 'val_auc', 
                                mode='max', 
                                save_best_only=True, 
                                verbose = 1)


callback_list = [earlystopping, checkpoint]

# %%
model_history=model.fit(train_dataset,
                        validation_data=valid_dataset,
                        epochs = 100,
                        callbacks = callback_list,
                        verbose = 1)
# Out:
# Epoch 1/100
# 21/21 [==============================] - ETA: 0s - loss: 1.3545 - auc: 0.7804
# Epoch 1: val_auc improved from -inf to 0.68810, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 890s 41s/step - loss: 1.3545 - auc: 0.7804 - val_loss: 4.5732 - val_auc: 0.6881
# Epoch 2/100
# 21/21 [==============================] - ETA: 0s - loss: 1.0871 - auc: 0.8290
# Epoch 2: val_auc improved from 0.68810 to 0.70723, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 86s 4s/step - loss: 1.0871 - auc: 0.8290 - val_loss: 2.8669 - val_auc: 0.7072
# Epoch 3/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9978 - auc: 0.8440
# Epoch 3: val_auc did not improve from 0.70723
# 21/21 [==============================] - 73s 3s/step - loss: 0.9978 - auc: 0.8440 - val_loss: 2.5087 - val_auc: 0.7044
# Epoch 4/100
# 21/21 [==============================] - ETA: 0s - loss: 0.9206 - auc: 0.8606
# Epoch 4: val_auc improved from 0.70723 to 0.71266, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 85s 4s/step - loss: 0.9206 - auc: 0.8606 - val_loss: 2.0825 - val_auc: 0.7127
# Epoch 5/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8815 - auc: 0.8672
# Epoch 5: val_auc improved from 0.71266 to 0.75286, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 88s 4s/step - loss: 0.8815 - auc: 0.8672 - val_loss: 1.7451 - val_auc: 0.7529
# Epoch 6/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8481 - auc: 0.8743
# Epoch 6: val_auc did not improve from 0.75286
# 21/21 [==============================] - 69s 3s/step - loss: 0.8481 - auc: 0.8743 - val_loss: 1.8572 - val_auc: 0.6487
# Epoch 7/100
# 21/21 [==============================] - ETA: 0s - loss: 0.8106 - auc: 0.8830
# Epoch 7: val_auc did not improve from 0.75286
# 21/21 [==============================] - 67s 3s/step - loss: 0.8106 - auc: 0.8830 - val_loss: 1.6283 - val_auc: 0.7210
# Epoch 8/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7757 - auc: 0.8913
# Epoch 8: val_auc did not improve from 0.75286
# 21/21 [==============================] - 67s 3s/step - loss: 0.7757 - auc: 0.8913 - val_loss: 1.6809 - val_auc: 0.7235
# Epoch 9/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7635 - auc: 0.8937
# Epoch 9: val_auc did not improve from 0.75286
# 21/21 [==============================] - 67s 3s/step - loss: 0.7635 - auc: 0.8937 - val_loss: 1.4946 - val_auc: 0.7273
# Epoch 10/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7320 - auc: 0.9014
# Epoch 10: val_auc did not improve from 0.75286
# 21/21 [==============================] - 67s 3s/step - loss: 0.7320 - auc: 0.9014 - val_loss: 1.5203 - val_auc: 0.7451
# Epoch 11/100
# 21/21 [==============================] - ETA: 0s - loss: 0.7188 - auc: 0.9053
# Epoch 11: val_auc did not improve from 0.75286
# 21/21 [==============================] - 67s 3s/step - loss: 0.7188 - auc: 0.9053 - val_loss: 1.5320 - val_auc: 0.7162
# Epoch 12/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6859 - auc: 0.9122
# Epoch 12: val_auc improved from 0.75286 to 0.76439, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 85s 4s/step - loss: 0.6859 - auc: 0.9122 - val_loss: 1.4255 - val_auc: 0.7644
# Epoch 13/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6641 - auc: 0.9178
# Epoch 13: val_auc did not improve from 0.76439
# 21/21 [==============================] - 72s 3s/step - loss: 0.6641 - auc: 0.9178 - val_loss: 1.4592 - val_auc: 0.7496
# Epoch 14/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6616 - auc: 0.9190
# Epoch 14: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.6616 - auc: 0.9190 - val_loss: 1.5515 - val_auc: 0.7471
# Epoch 15/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6610 - auc: 0.9191
# Epoch 15: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.6610 - auc: 0.9191 - val_loss: 1.6647 - val_auc: 0.7198
# Epoch 16/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6410 - auc: 0.9241
# Epoch 16: val_auc did not improve from 0.76439
# 21/21 [==============================] - 66s 3s/step - loss: 0.6410 - auc: 0.9241 - val_loss: 1.4489 - val_auc: 0.7419
# Epoch 17/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6329 - auc: 0.9252
# Epoch 17: val_auc did not improve from 0.76439
# 21/21 [==============================] - 68s 3s/step - loss: 0.6329 - auc: 0.9252 - val_loss: 1.5170 - val_auc: 0.7366
# Epoch 18/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6201 - auc: 0.9292
# Epoch 18: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.6201 - auc: 0.9292 - val_loss: 1.5414 - val_auc: 0.7615
# Epoch 19/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6169 - auc: 0.9291
# Epoch 19: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.6169 - auc: 0.9291 - val_loss: 1.6096 - val_auc: 0.7485
# Epoch 20/100
# 21/21 [==============================] - ETA: 0s - loss: 0.6123 - auc: 0.9304
# Epoch 20: val_auc did not improve from 0.76439
# 21/21 [==============================] - 68s 3s/step - loss: 0.6123 - auc: 0.9304 - val_loss: 1.5091 - val_auc: 0.7597
# Epoch 21/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5894 - auc: 0.9352
# Epoch 21: val_auc did not improve from 0.76439
# 21/21 [==============================] - 66s 3s/step - loss: 0.5894 - auc: 0.9352 - val_loss: 1.4710 - val_auc: 0.7565
# Epoch 22/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5816 - auc: 0.9365
# Epoch 22: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.5816 - auc: 0.9365 - val_loss: 1.6884 - val_auc: 0.7206
# Epoch 23/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5563 - auc: 0.9422
# Epoch 23: val_auc did not improve from 0.76439
# 21/21 [==============================] - 68s 3s/step - loss: 0.5563 - auc: 0.9422 - val_loss: 1.6066 - val_auc: 0.7592
# Epoch 24/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5668 - auc: 0.9408
# Epoch 24: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.5668 - auc: 0.9408 - val_loss: 1.7693 - val_auc: 0.7252
# Epoch 25/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5663 - auc: 0.9412
# Epoch 25: val_auc did not improve from 0.76439
# 21/21 [==============================] - 67s 3s/step - loss: 0.5663 - auc: 0.9412 - val_loss: 1.6267 - val_auc: 0.7535
# Epoch 26/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5456 - auc: 0.9441
# Epoch 26: val_auc did not improve from 0.76439
# 21/21 [==============================] - 68s 3s/step - loss: 0.5456 - auc: 0.9441 - val_loss: 1.7421 - val_auc: 0.7595
# Epoch 27/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5450 - auc: 0.9447
# Epoch 27: val_auc improved from 0.76439 to 0.78218, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 84s 4s/step - loss: 0.5450 - auc: 0.9447 - val_loss: 1.5675 - val_auc: 0.7822
# Epoch 28/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5362 - auc: 0.9461
# Epoch 28: val_auc did not improve from 0.78218
# 21/21 [==============================] - 72s 3s/step - loss: 0.5362 - auc: 0.9461 - val_loss: 1.5210 - val_auc: 0.7788
# Epoch 29/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5235 - auc: 0.9489
# Epoch 29: val_auc did not improve from 0.78218
# 21/21 [==============================] - 68s 3s/step - loss: 0.5235 - auc: 0.9489 - val_loss: 1.6344 - val_auc: 0.7658
# Epoch 30/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5405 - auc: 0.9455
# Epoch 30: val_auc did not improve from 0.78218
# 21/21 [==============================] - 67s 3s/step - loss: 0.5405 - auc: 0.9455 - val_loss: 1.5565 - val_auc: 0.7785
# Epoch 31/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5142 - auc: 0.9507
# Epoch 31: val_auc did not improve from 0.78218
# 21/21 [==============================] - 67s 3s/step - loss: 0.5142 - auc: 0.9507 - val_loss: 1.6485 - val_auc: 0.7530
# Epoch 32/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5147 - auc: 0.9509
# Epoch 32: val_auc did not improve from 0.78218
# 21/21 [==============================] - 68s 3s/step - loss: 0.5147 - auc: 0.9509 - val_loss: 1.8268 - val_auc: 0.7279
# Epoch 33/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5102 - auc: 0.9515
# Epoch 33: val_auc improved from 0.78218 to 0.79642, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 83s 4s/step - loss: 0.5102 - auc: 0.9515 - val_loss: 1.5503 - val_auc: 0.7964
# Epoch 34/100
# 21/21 [==============================] - ETA: 0s - loss: 0.5193 - auc: 0.9496
# Epoch 34: val_auc did not improve from 0.79642
# 21/21 [==============================] - 72s 4s/step - loss: 0.5193 - auc: 0.9496 - val_loss: 1.8045 - val_auc: 0.7564
# Epoch 35/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4947 - auc: 0.9540
# Epoch 35: val_auc did not improve from 0.79642
# 21/21 [==============================] - 67s 3s/step - loss: 0.4947 - auc: 0.9540 - val_loss: 1.6389 - val_auc: 0.7793
# Epoch 36/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4964 - auc: 0.9543
# Epoch 36: val_auc did not improve from 0.79642
# 21/21 [==============================] - 67s 3s/step - loss: 0.4964 - auc: 0.9543 - val_loss: 1.8058 - val_auc: 0.7610
# Epoch 37/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4827 - auc: 0.9567
# Epoch 37: val_auc did not improve from 0.79642
# 21/21 [==============================] - 68s 3s/step - loss: 0.4827 - auc: 0.9567 - val_loss: 1.7204 - val_auc: 0.7708
# Epoch 38/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4875 - auc: 0.9556
# Epoch 38: val_auc did not improve from 0.79642
# 21/21 [==============================] - 67s 3s/step - loss: 0.4875 - auc: 0.9556 - val_loss: 1.8796 - val_auc: 0.7550
# Epoch 39/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4747 - auc: 0.9577
# Epoch 39: val_auc did not improve from 0.79642
# 21/21 [==============================] - 67s 3s/step - loss: 0.4747 - auc: 0.9577 - val_loss: 1.7412 - val_auc: 0.7765
# Epoch 40/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4782 - auc: 0.9574
# Epoch 40: val_auc did not improve from 0.79642
# 21/21 [==============================] - 68s 3s/step - loss: 0.4782 - auc: 0.9574 - val_loss: 1.7801 - val_auc: 0.7700
# Epoch 41/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4773 - auc: 0.9573
# Epoch 41: val_auc did not improve from 0.79642
# 21/21 [==============================] - 67s 3s/step - loss: 0.4773 - auc: 0.9573 - val_loss: 1.8374 - val_auc: 0.7573
# Epoch 42/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4619 - auc: 0.9601
# Epoch 42: val_auc did not improve from 0.79642
# 21/21 [==============================] - 67s 3s/step - loss: 0.4619 - auc: 0.9601 - val_loss: 1.9097 - val_auc: 0.7569
# Epoch 43/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4568 - auc: 0.9611
# Epoch 43: val_auc did not improve from 0.79642
# 21/21 [==============================] - 68s 3s/step - loss: 0.4568 - auc: 0.9611 - val_loss: 1.6952 - val_auc: 0.7791
# Epoch 44/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4592 - auc: 0.9605
# Epoch 44: val_auc improved from 0.79642 to 0.79754, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 84s 4s/step - loss: 0.4592 - auc: 0.9605 - val_loss: 1.6940 - val_auc: 0.7975
# Epoch 45/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4487 - auc: 0.9620
# Epoch 45: val_auc did not improve from 0.79754
# 21/21 [==============================] - 72s 3s/step - loss: 0.4487 - auc: 0.9620 - val_loss: 1.6186 - val_auc: 0.7917
# Epoch 46/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4271 - auc: 0.9658
# Epoch 46: val_auc improved from 0.79754 to 0.79968, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 85s 4s/step - loss: 0.4271 - auc: 0.9658 - val_loss: 1.6594 - val_auc: 0.7997
# Epoch 47/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4405 - auc: 0.9637
# Epoch 47: val_auc did not improve from 0.79968
# 21/21 [==============================] - 68s 3s/step - loss: 0.4405 - auc: 0.9637 - val_loss: 1.6604 - val_auc: 0.7852
# Epoch 48/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4404 - auc: 0.9637
# Epoch 48: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.4404 - auc: 0.9637 - val_loss: 1.8459 - val_auc: 0.7637
# Epoch 49/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4311 - auc: 0.9651
# Epoch 49: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.4311 - auc: 0.9651 - val_loss: 1.6080 - val_auc: 0.7878
# Epoch 50/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4272 - auc: 0.9657
# Epoch 50: val_auc did not improve from 0.79968
# 21/21 [==============================] - 68s 3s/step - loss: 0.4272 - auc: 0.9657 - val_loss: 1.8351 - val_auc: 0.7684
# Epoch 51/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4346 - auc: 0.9645
# Epoch 51: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.4346 - auc: 0.9645 - val_loss: 1.8025 - val_auc: 0.7683
# Epoch 52/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4192 - auc: 0.9672
# Epoch 52: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.4192 - auc: 0.9672 - val_loss: 1.8547 - val_auc: 0.7459
# Epoch 53/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4254 - auc: 0.9661
# Epoch 53: val_auc did not improve from 0.79968
# 21/21 [==============================] - 68s 3s/step - loss: 0.4254 - auc: 0.9661 - val_loss: 1.9961 - val_auc: 0.7313
# Epoch 54/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4147 - auc: 0.9676
# Epoch 54: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.4147 - auc: 0.9676 - val_loss: 1.7970 - val_auc: 0.7690
# Epoch 55/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3962 - auc: 0.9705
# Epoch 55: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.3962 - auc: 0.9705 - val_loss: 1.7110 - val_auc: 0.7883
# Epoch 56/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3880 - auc: 0.9720
# Epoch 56: val_auc did not improve from 0.79968
# 21/21 [==============================] - 67s 3s/step - loss: 0.3880 - auc: 0.9720 - val_loss: 1.7620 - val_auc: 0.7875
# Epoch 57/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4041 - auc: 0.9695
# Epoch 57: val_auc improved from 0.79968 to 0.80879, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 85s 4s/step - loss: 0.4041 - auc: 0.9695 - val_loss: 1.5961 - val_auc: 0.8088
# Epoch 58/100
# 21/21 [==============================] - ETA: 0s - loss: 0.4079 - auc: 0.9689
# Epoch 58: val_auc did not improve from 0.80879
# 21/21 [==============================] - 74s 3s/step - loss: 0.4079 - auc: 0.9689 - val_loss: 1.5856 - val_auc: 0.8055
# Epoch 59/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3887 - auc: 0.9714
# Epoch 59: val_auc did not improve from 0.80879
# 21/21 [==============================] - 67s 3s/step - loss: 0.3887 - auc: 0.9714 - val_loss: 1.5483 - val_auc: 0.8042
# Epoch 60/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3851 - auc: 0.9719
# Epoch 60: val_auc did not improve from 0.80879
# 21/21 [==============================] - 67s 3s/step - loss: 0.3851 - auc: 0.9719 - val_loss: 1.6806 - val_auc: 0.7974
# Epoch 61/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3916 - auc: 0.9712
# Epoch 61: val_auc did not improve from 0.80879
# 21/21 [==============================] - 67s 3s/step - loss: 0.3916 - auc: 0.9712 - val_loss: 1.6309 - val_auc: 0.8033
# Epoch 62/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3773 - auc: 0.9732
# Epoch 62: val_auc did not improve from 0.80879
# 21/21 [==============================] - 68s 3s/step - loss: 0.3773 - auc: 0.9732 - val_loss: 1.6960 - val_auc: 0.7977
# Epoch 63/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3762 - auc: 0.9735
# Epoch 63: val_auc did not improve from 0.80879
# 21/21 [==============================] - 67s 3s/step - loss: 0.3762 - auc: 0.9735 - val_loss: 1.7961 - val_auc: 0.7795
# Epoch 64/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3786 - auc: 0.9728
# Epoch 64: val_auc did not improve from 0.80879
# 21/21 [==============================] - 66s 3s/step - loss: 0.3786 - auc: 0.9728 - val_loss: 1.7994 - val_auc: 0.7918
# Epoch 65/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3705 - auc: 0.9741
# Epoch 65: val_auc improved from 0.80879 to 0.81480, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 84s 4s/step - loss: 0.3705 - auc: 0.9741 - val_loss: 1.5644 - val_auc: 0.8148
# Epoch 66/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3609 - auc: 0.9753
# Epoch 66: val_auc did not improve from 0.81480
# 21/21 [==============================] - 68s 3s/step - loss: 0.3609 - auc: 0.9753 - val_loss: 1.7749 - val_auc: 0.7802
# Epoch 67/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3783 - auc: 0.9730
# Epoch 67: val_auc did not improve from 0.81480
# 21/21 [==============================] - 69s 3s/step - loss: 0.3783 - auc: 0.9730 - val_loss: 1.7173 - val_auc: 0.7956
# Epoch 68/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3672 - auc: 0.9743
# Epoch 68: val_auc did not improve from 0.81480
# 21/21 [==============================] - 67s 3s/step - loss: 0.3672 - auc: 0.9743 - val_loss: 1.6501 - val_auc: 0.8116
# Epoch 69/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3594 - auc: 0.9756
# Epoch 69: val_auc did not improve from 0.81480
# 21/21 [==============================] - 67s 3s/step - loss: 0.3594 - auc: 0.9756 - val_loss: 1.7742 - val_auc: 0.7844
# Epoch 70/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3609 - auc: 0.9756
# Epoch 70: val_auc did not improve from 0.81480
# 21/21 [==============================] - 67s 3s/step - loss: 0.3609 - auc: 0.9756 - val_loss: 1.6475 - val_auc: 0.8051
# Epoch 71/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3726 - auc: 0.9740
# Epoch 71: val_auc improved from 0.81480 to 0.81697, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 88s 4s/step - loss: 0.3726 - auc: 0.9740 - val_loss: 1.5814 - val_auc: 0.8170
# Epoch 72/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3566 - auc: 0.9760
# Epoch 72: val_auc did not improve from 0.81697
# 21/21 [==============================] - 72s 3s/step - loss: 0.3566 - auc: 0.9760 - val_loss: 1.7659 - val_auc: 0.7932
# Epoch 73/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3351 - auc: 0.9788
# Epoch 73: val_auc did not improve from 0.81697
# 21/21 [==============================] - 68s 3s/step - loss: 0.3351 - auc: 0.9788 - val_loss: 1.7726 - val_auc: 0.7899
# Epoch 74/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3286 - auc: 0.9793
# Epoch 74: val_auc did not improve from 0.81697
# 21/21 [==============================] - 67s 3s/step - loss: 0.3286 - auc: 0.9793 - val_loss: 1.7688 - val_auc: 0.7938
# Epoch 75/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3398 - auc: 0.9780
# Epoch 75: val_auc did not improve from 0.81697
# 21/21 [==============================] - 67s 3s/step - loss: 0.3398 - auc: 0.9780 - val_loss: 1.7754 - val_auc: 0.7841
# Epoch 76/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3568 - auc: 0.9757
# Epoch 76: val_auc did not improve from 0.81697
# 21/21 [==============================] - 67s 3s/step - loss: 0.3568 - auc: 0.9757 - val_loss: 1.9427 - val_auc: 0.7777
# Epoch 77/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3394 - auc: 0.9782
# Epoch 77: val_auc improved from 0.81697 to 0.82065, saving model to /content/drive/MyDrive/Colab Notebooks/best_weights.hdf5
# 21/21 [==============================] - 85s 4s/step - loss: 0.3394 - auc: 0.9782 - val_loss: 1.5748 - val_auc: 0.8206
# Epoch 78/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3329 - auc: 0.9788
# Epoch 78: val_auc did not improve from 0.82065
# 21/21 [==============================] - 72s 3s/step - loss: 0.3329 - auc: 0.9788 - val_loss: 1.6803 - val_auc: 0.8120
# Epoch 79/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3242 - auc: 0.9801
# Epoch 79: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3242 - auc: 0.9801 - val_loss: 1.8414 - val_auc: 0.8001
# Epoch 80/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3213 - auc: 0.9801
# Epoch 80: val_auc did not improve from 0.82065
# 21/21 [==============================] - 68s 3s/step - loss: 0.3213 - auc: 0.9801 - val_loss: 1.9348 - val_auc: 0.7727
# Epoch 81/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3384 - auc: 0.9782
# Epoch 81: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3384 - auc: 0.9782 - val_loss: 1.7871 - val_auc: 0.8053
# Epoch 82/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3202 - auc: 0.9804
# Epoch 82: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3202 - auc: 0.9804 - val_loss: 1.8933 - val_auc: 0.7895
# Epoch 83/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3188 - auc: 0.9806
# Epoch 83: val_auc did not improve from 0.82065
# 21/21 [==============================] - 68s 3s/step - loss: 0.3188 - auc: 0.9806 - val_loss: 1.8100 - val_auc: 0.8026
# Epoch 84/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3209 - auc: 0.9804
# Epoch 84: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3209 - auc: 0.9804 - val_loss: 1.7371 - val_auc: 0.8117
# Epoch 85/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3193 - auc: 0.9807
# Epoch 85: val_auc did not improve from 0.82065
# 21/21 [==============================] - 66s 3s/step - loss: 0.3193 - auc: 0.9807 - val_loss: 1.7804 - val_auc: 0.7959
# Epoch 86/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2959 - auc: 0.9830
# Epoch 86: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.2959 - auc: 0.9830 - val_loss: 1.9568 - val_auc: 0.7812
# Epoch 87/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3051 - auc: 0.9822
# Epoch 87: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3051 - auc: 0.9822 - val_loss: 1.8911 - val_auc: 0.7886
# Epoch 88/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3086 - auc: 0.9816
# Epoch 88: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3086 - auc: 0.9816 - val_loss: 1.8474 - val_auc: 0.7917
# Epoch 89/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3143 - auc: 0.9810
# Epoch 89: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3143 - auc: 0.9810 - val_loss: 1.8098 - val_auc: 0.8017
# Epoch 90/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3046 - auc: 0.9824
# Epoch 90: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.3046 - auc: 0.9824 - val_loss: 1.9856 - val_auc: 0.7740
# Epoch 91/100
# 21/21 [==============================] - ETA: 0s - loss: 0.2996 - auc: 0.9827
# Epoch 91: val_auc did not improve from 0.82065
# 21/21 [==============================] - 67s 3s/step - loss: 0.2996 - auc: 0.9827 - val_loss: 1.9627 - val_auc: 0.7824
# Epoch 92/100
# 21/21 [==============================] - ETA: 0s - loss: 0.3027 - auc: 0.9824
# Epoch 92: val_auc did not improve from 0.82065
# 21/21 [==============================] - 66s 3s/step - loss: 0.3027 - auc: 0.9824 - val_loss: 1.7440 - val_auc: 0.8152
# Epoch 92: early stopping

# %%
#MODEL EVALUATION

# %%
# Summarize history for loss

plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Summarize history for loss

plt.plot(model_history.history['auc'])
plt.plot(model_history.history['val_auc'])
plt.title('Model AUC')
plt.ylabel('AUC')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left', bbox_to_anchor=(1,1))
plt.show()

# %%
# Test Data 

test_dataset  = test_datagen.flow_from_directory(directory = '/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test',
                                                 target_size = (224,224),
                                                 class_mode = 'categorical',
                                                 batch_size = 128)
# Out:
# Found 1279 images belonging to 4 classes.

# %%
# Evaluating Loss and AUC

model.evaluate(test_dataset)
# Out:
# 10/10 [==============================] - 10s 1s/step - loss: 0.9980 - auc: 0.9187
# [0.9980432391166687, 0.9187169671058655]

# %%
# Test Case 1: Non-Dementia

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Non_Demented/32 (91).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
#answer = model.predict_classes(img)
answer = np.argmax(model.predict(img), axis=1)
#probability = round(np.max(model.predict_proba(img)*100),2)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 67ms/step
# 100.0 % chances are there that the image is Non_Demented

# %%
# Test Case 2: Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Mild_Demented/26 (25).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 48ms/step
# 90.37 % chances are there that the image is Mild_Demented

# %%
# Test Case 3: Moderate Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Moderate_Demented/30 (2).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 50ms/step
# 58.51 % chances are there that the image is Very_Mild_Demented

# %%
# Test Case 4: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Very_Mild_Demented/26 (51).jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 51ms/step
# 76.56 % chances are there that the image is Non_Demented

# %%
# Test Case 5: Very Mild Demented

dic = test_dataset.class_indices
idc = {k:v for v, k in dic.items()}

img = load_img('/content/drive/MyDrive/Colab Notebooks/AlzheimerDataset/test/Very_Mild_Demented/32.jpg', target_size = (224,224,3))
img = img_to_array(img)
img = img/255
imshow(img)
plt.axis('off')
img = np.expand_dims(img,axis=0)
answer = np.argmax(model.predict(img), axis=1)
probability=round(np.max(model.predict_on_batch(img)*100),2)
print(probability, '% chances are there that the image is',idc[answer[0]])
# Out:
# 1/1 [==============================] - 0s 41ms/step
# 99.04 % chances are there that the image is Non_Demented

# %%
#Conclusion:

#So, we have finally built are deep learning model using DenseNet162 transfer learning algorithm and acheived and AUC-90%.
